# %% [markdown]
# ## Función de Daño

# %% [markdown]
# Tras haber usado mediciones de dos modelos, Regresión Logística y Random Forest se han sacado los siguientes pesos para cada medición:
#
# **Random Forest**
#
# Piezo $\rightarrow 45.67$%
#
# Temperatura $\rightarrow 13.79$%
#
# Accelerómetro $\rightarrow 40.52$%
#
# **Logistic Regression**
#
# Piezo $\rightarrow 65.50$%
#
# Temperatura $\rightarrow 1.38$%
#
# Accelerómetro $\rightarrow 33.12$%

# %% [markdown]
# Haciendo la media con estos esos tendríamos los siguientes pesos:
#
# Piezo $\rightarrow 55.58$%
#
# Temperatura $\rightarrow 7.585$%
#
# Accelerómetro $\rightarrow 36.82$%
#
#
# Como las mediciones del dataset se han hecho en un caso ligeramente distinto al nuestro, nos guiamos por ellas pero variamos ligeramente los porcentajes usando intuiciones físicas de nuestro caso en específico.
#
# Piezo $\rightarrow 45$%
#
# Temperatura $\rightarrow 10$%
#
# Accelerómetro $\rightarrow 45$%

# %% [markdown]
# ¿Porque bajamos un 10.5% el peso del **Piezo**?
#
# Pasa eliminar falsos positivos causados por interferencias eléctricas en los cables del piezo causados por el paso del tren.
#
# ¿Porque subimos el accelerómetro?
#
# Pese a que el dataset tenga los datos de las mismas mediciones, el caso de uso y medición es distinto. En el dataset se realizaron las mediciones de un edificio, por lo que las vibraciones son menores que en el caso del paso de un tren, por lo que decidimos subir un 8.18%.

# %% [markdown]
# ### Función de daño final
#
# Con estos pesos, la función de daño se nos quedaría de la siguiente forma:
#
# ### $ D = 0.45P + 0.10T + 0.45A $
